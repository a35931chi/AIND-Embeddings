# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils
# Out:
# c:\users\inves\appdata\local\programs\python\python35\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()
# Out:
# Text8 Dataset: 31.4MB [00:15, 2.06MB/s]

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
print(len(int_words))
print(int_words[:10])
# Out:
# 16680599
# [5237, 3083, 11, 5, 194, 1, 3134, 45, 58, 155]

# %%
## Your code here
from collections import Counter
import random

threshold = 1e-5 #this is kind of arbitrary??

word_counts = Counter(int_words) #calculate the frequency of all the words in the dataset
total_count = len(int_words) #get the number of total words
freqs = {word: count / total_count for word, count in word_counts.items()} #word count divided by total count
# if % is lower than a certain threshold, the word is discarded
p_drop = {word: 1 - np.sqrt(threshold / freqs[word]) for word in word_counts} #get the probability

# The final subsampled word list, we are dropping/keeping some words based on it's probabilities
#train_words = {word for word in int_words if p_drop[word] < random.random()}
train_words = [word for word in int_words if random.random() < (1 - p_drop[word])]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size = 5):
    ''' Get a list of words in a window around an index. '''
    # Your code here
    #generate a random window
    R = np.random.randint(1, window_size + 1)
    
    #define start index and end index. note that index shouldn't be less than 0
    start = idx - R if (idx - R) > 0 else 0
    stop = idx + R
    
    #look for target word (history + future), and get rid of duplicates
    target_words = set(words[start:idx] + words[idx + 1 : stop + 1])
    
    return list(target_words) #then return as a list, convert from set

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph() #I don't think I've seen tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name = 'inputs')
    labels = tf.placeholder(tf.int32, [None, None], name = 'labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    # create embedding weight matrix here
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1))
    # use tf.nn.embedding_lookup to get the hidden layer output
    embed = tf.nn.embedding_lookup(embedding, inputs) #values of the hidden layer

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    # create softmax weight matrix here
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev = 0.1))
    # create softmax biases here
    softmax_b = tf.Variable(tf.zeros(n_vocab))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, labels,
                                     embed, n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)
# Out:
# WARNING:tensorflow:From c:\users\inves\appdata\local\programs\python\python35\lib\site-packages\tensorflow\python\ops\nn_impl.py:1310: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See tf.nn.softmax_cross_entropy_with_logits_v2.

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))
# Out:
# WARNING:tensorflow:From <ipython-input-19-2aa168c49a56>:13: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
#this is fairly standard
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6308 0.2939 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6347 0.2911 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.5172 0.2920 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.6066 0.2894 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.5493 0.2871 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5500 0.2900 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5190 0.2902 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5237 0.2832 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4867 0.2831 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4344 0.2791 sec/batch
# Nearest to between: next, effects, half, prolonged, pareto, salvatore, prabang, webcomics,
# Nearest to states: cool, taisho, proteobacteria, strategies, frosts, roscher, puncture, stands,
# Nearest to five: pankhurst, descendants, refineries, unchallenged, buckles, factored, examine, alumina,
# Nearest to zero: illustration, looting, subconscious, twenty, ringing, identifications, mangrove, asc,
# Nearest to use: watcher, davenport, redshifted, nevers, parent, oldest, benevolence, bhra,
# Nearest to known: to, bessel, dismutase, singhasari, pouch, janis, boitano, rautha,
# Nearest to used: aford, life, aisle, mushrooms, festive, gettysburg, ippon, asymptotes,
# Nearest to three: meteorology, formerly, trailing, methuen, tz, contracts, measurement, revival,
# Nearest to nobel: placidia, interpretations, deviation, placate, inaccessibility, unaccounted, aphasia, attar,
# Nearest to paris: virgins, minors, mussorgsky, dembski, aries, hyperspace, progressing, portmanteau,
# Nearest to question: misinterpreted, kazimierz, kongsberg, diwan, dravidian, hackett, turco, wasps,
# Nearest to mean: originals, dmt, madness, gospel, fracture, jules, ryaku, dissolving,
# Nearest to discovered: viol, fights, riverine, establish, affordability, hepatic, publish, amati,
# Nearest to know: polonaise, saddled, versuch, abstractly, hmong, industrialist, permitted, alliteration,
# Nearest to orthodox: sniffing, contemporaries, focusing, hugged, seminars, rancher, heiland, insignificant,
# Nearest to bible: silica, successively, dyess, savate, radars, voiceless, aid, looney,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4882 0.2962 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3727 0.2934 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3285 0.2889 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2556 0.2852 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1826 0.2853 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1549 0.2875 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.1152 0.2862 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0801 0.2854 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0109 0.2884 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9901 0.2964 sec/batch
# Nearest to between: next, effects, half, prolonged, greatest, webcomics, fibre, type,
# Nearest to states: cool, strategies, stands, objects, massed, puncture, interim, taisho,
# Nearest to five: descendants, pankhurst, examine, refineries, unchallenged, factored, slang, hbo,
# Nearest to zero: illustration, twenty, looting, more, asc, depicted, subconscious, ad,
# Nearest to use: parent, redshifted, davenport, oldest, a, varying, watcher, hide,
# Nearest to known: to, frequency, tibetan, pouch, photographic, george, measurements, bessel,
# Nearest to used: aford, life, mushrooms, festive, aisle, story, abducted, assassinated,
# Nearest to three: formerly, trailing, meteorology, contracts, measurement, agents, revival, campaign,
# Nearest to nobel: interpretations, placidia, deviation, unaccounted, aphasia, attar, t, weld,
# Nearest to paris: minors, virgins, located, southern, great, fur, preferences, portmanteau,
# Nearest to question: misinterpreted, brave, reinforced, diwan, wiles, teach, dravidian, hackett,
# Nearest to mean: originals, dmt, madness, gospel, fracture, jules, governs, sunday,
# Nearest to discovered: establish, fights, publish, widespread, ambient, viol, tell, stands,
# Nearest to know: polonaise, versuch, italy, industrialist, permitted, falling, saddled, muscle,
# Nearest to orthodox: focusing, contemporaries, represented, sonatas, seminars, sniffing, insignificant, royals,
# Nearest to bible: silica, aid, radars, dyess, voiceless, junction, bases, savate,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9408 0.2904 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.9024 0.2860 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8971 0.2845 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8502 0.2980 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8297 0.2853 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8120 0.2889 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.7857 0.2873 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7673 0.2891 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7881 0.2874 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7709 0.2928 sec/batch
# Nearest to between: next, effects, prolonged, half, greatest, org, fibre, webcomics,
# Nearest to states: strategies, cool, stands, cradle, interim, puncture, commission, knees,
# Nearest to five: pankhurst, descendants, unpaved, examine, unchallenged, b, refineries, slang,
# Nearest to zero: illustration, twenty, looting, asc, ad, bayonne, kilometres, seven,
# Nearest to use: parent, redshifted, davenport, watcher, abuses, oldest, hide, varying,
# Nearest to known: to, citizenry, bessel, pouch, photographic, tibetan, prince, perrin,
# Nearest to used: aford, life, festive, mushrooms, aisle, encyclopedia, gettysburg, flu,
# Nearest to three: formerly, meteorology, trailing, tz, contracts, rap, nader, packing,
# Nearest to nobel: interpretations, attar, deviation, placidia, cameron, unattractive, struggling, automatic,
# Nearest to paris: virgins, minors, southern, portmanteau, championship, dembski, aries, progressing,
# Nearest to question: misinterpreted, brave, teach, cultural, hackett, reinforced, creation, clarified,
# Nearest to mean: originals, dmt, madness, gospel, fracture, dissolving, jules, vestiges,
# Nearest to discovered: fights, ambient, establish, widespread, viol, riverine, stance, deceased,
# Nearest to know: polonaise, industrialist, permitted, versuch, falling, hmong, shifted, offence,
# Nearest to orthodox: contemporaries, focusing, sniffing, insignificant, seminars, shady, represented, akihabara,
# Nearest to bible: silica, aid, radars, successively, dyess, savate, distinguishing, voiceless,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7524 0.2950 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7502 0.2886 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7418 0.2888 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.6970 0.2947 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7652 0.2916 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.6653 0.2887 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7218 0.2865 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7366 0.2893 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.6931 0.2920 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6678 0.2892 sec/batch
# Nearest to between: effects, prolonged, next, half, greatest, webcomics, prabang, gymnosperms,
# Nearest to states: strategies, relations, interim, tamers, puncture, stands, commission, cradle,
# Nearest to five: b, unpaved, pankhurst, descendants, brahmaputra, examine, years, painter,
# Nearest to zero: seven, ivoire, bayonne, asc, looting, illustration, ambassadors, migrant,
# Nearest to use: parent, redshifted, davenport, watcher, varying, abuses, vodafone, testing,
# Nearest to known: citizenry, to, pouch, bessel, janis, dismutase, brushed, bogdanovich,
# Nearest to used: aford, festive, life, mushrooms, aisle, bundling, singaporean, flu,
# Nearest to three: formerly, tz, unpaved, six, seven, eight, nader, rap,
# Nearest to nobel: attar, interpretations, harriet, unattractive, composer, recipients, cameron, gesenius,
# Nearest to paris: virgins, dembski, minors, aries, southern, progressing, portmanteau, great,
# Nearest to question: misinterpreted, clarified, teach, hackett, dravidian, brave, myths, creation,
# Nearest to mean: originals, dmt, madness, dissolving, gospel, fracture, vestiges, sx,
# Nearest to discovered: fights, viol, riverine, widespread, ambient, deceased, establish, reincarnations,
# Nearest to know: polonaise, industrialist, hmong, alliteration, shakuhachi, offence, permitted, shifted,
# Nearest to orthodox: contemporaries, sniffing, focusing, seminars, insignificant, wight, rancher, meticulously,
# Nearest to bible: silica, successively, aid, radars, sneaking, distinguishing, savate, subsidy,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6610 0.2927 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6453 0.2868 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6293 0.2889 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6180 0.2882 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6579 0.2882 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6454 0.2924 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.6012 0.2092 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5503 0.2893 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5249 0.2870 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.4966 0.2918 sec/batch
# Nearest to between: effects, half, gymnosperms, type, next, prolonged, ler, lineages,
# Nearest to states: manger, tamers, relations, edelweiss, socialist, strategies, interim, stands,
# Nearest to five: b, painter, unpaved, pankhurst, brahmaputra, violinist, composer, descendants,
# Nearest to zero: seven, ivoire, migrant, two, kilometres, bayonne, average, asc,
# Nearest to use: parent, varying, redshifted, watcher, davenport, testing, vodafone, hide,
# Nearest to known: to, citizenry, pouch, janis, bessel, bando, dismutase, tibetan,
# Nearest to used: aford, bundling, format, festive, mushrooms, mmu, flu, singaporean,
# Nearest to three: six, seven, formerly, eight, unpaved, tz, violinist, musician,
# Nearest to nobel: attar, composer, harriet, physicist, wrestler, unattractive, interpretations, cameron,
# Nearest to paris: virgins, dembski, great, tunku, aries, mussorgsky, healy, southern,
# Nearest to question: misinterpreted, clarified, teach, sake, cultural, dravidian, diwan, myths,
# Nearest to mean: originals, madness, dmt, vestiges, dissolving, gospel, sx, think,
# Nearest to discovered: viol, fights, ambient, riverine, widespread, reincarnations, deceased, binder,
# Nearest to know: polonaise, alliteration, abstractly, hmong, shakuhachi, offence, industrialist, permitted,
# Nearest to orthodox: contemporaries, sniffing, rancher, focusing, seminars, wight, insignificant, meticulously,
# Nearest to bible: silica, successively, sneaking, aid, radars, distinguishing, savate, obsession,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.5049 0.2943 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.4816 0.2907 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4421 0.2901 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5350 0.2929 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4789 0.2929 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4730 0.2940 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4439 0.2819 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.4133 0.2820 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4361 0.2904 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4254 0.2799 sec/batch
# Nearest to between: effects, type, half, prolonged, gymnosperms, prabang, lineages, unfermented,
# Nearest to states: manger, relations, socialist, tamers, edelweiss, tortosa, commission, strategies,
# Nearest to five: unpaved, pankhurst, utc, b, zero, years, brahmaputra, female,
# Nearest to zero: seven, ivoire, two, migrant, average, kilometres, infant, bayonne,
# Nearest to use: parent, redshifted, varying, watcher, davenport, vodafone, testing, nevers,
# Nearest to known: bessel, pouch, to, citizenry, janis, bando, dismutase, tibetan,
# Nearest to used: aford, bundling, flu, festive, mushrooms, seemingly, format, carelessness,
# Nearest to three: six, formerly, unpaved, seven, tz, zero, eight, jimmie,
# Nearest to nobel: attar, composer, harriet, physicist, unattractive, cameron, wrestler, recipients,
# Nearest to paris: virgins, dembski, great, tunku, mae, mussorgsky, healy, kiel,
# Nearest to question: misinterpreted, clarified, teach, sake, cultural, creation, diwan, dravidian,
# Nearest to mean: originals, dmt, madness, vestiges, gospel, relativistic, subtracted, dissolving,
# Nearest to discovered: viol, ambient, fights, reincarnations, widespread, riverine, deceased, affordability,
# Nearest to know: polonaise, alliteration, abstractly, hmong, shakuhachi, else, victim, offence,
# Nearest to orthodox: contemporaries, sniffing, rancher, focusing, insignificant, meticulously, woodstock, seminars,
# Nearest to bible: successively, sneaking, silica, distinguishing, jewish, savate, aid, obsession,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4616 0.2891 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4154 0.2897 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4308 0.2831 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.3985 0.2882 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4112 0.2863 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4233 0.2855 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.4061 0.2856 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3631 0.2941 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4051 0.2928 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3904 0.2911 sec/batch
# Nearest to between: half, effects, unfermented, gymnosperms, prabang, type, lineages, therapists,
# Nearest to states: socialist, manger, relations, edelweiss, commission, tran, tamers, abolishing,
# Nearest to five: pankhurst, utc, unpaved, zero, years, brahmaputra, b, two,
# Nearest to zero: seven, two, ivoire, migrant, infant, average, five, asc,
# Nearest to use: varying, parent, redshifted, watcher, vodafone, testing, nevers, davenport,
# Nearest to known: bessel, bando, dismutase, citizenry, pouch, janis, to, spaceflights,
# Nearest to used: aford, bundling, flu, cervical, format, festive, carelessness, singaporean,
# Nearest to three: seven, six, formerly, unpaved, eight, tz, jimmie, sumter,
# Nearest to nobel: attar, composer, harriet, physicist, cameron, belmont, unattractive, turin,
# Nearest to paris: virgins, dembski, great, hulme, mae, healy, vigo, aries,
# Nearest to question: misinterpreted, clarified, teach, creation, neurophysiology, sake, dravidian, egoism,
# Nearest to mean: dmt, originals, madness, vestiges, dissolving, sx, gospel, postulates,
# Nearest to discovered: ambient, viol, boggy, reincarnations, fights, widespread, noting, riverine,
# Nearest to know: polonaise, else, shakuhachi, offence, alliteration, abstractly, victim, hmong,
# Nearest to orthodox: oriental, contemporaries, sniffing, rancher, terengganu, meticulously, beliefs, sacred,
# Nearest to bible: jewish, distinguishing, successively, tanakh, sees, sneaking, theology, old,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3761 0.2933 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.4019 0.2990 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3602 0.2921 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3492 0.2881 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.4042 0.2851 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3887 0.2901 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3753 0.2833 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3972 0.2767 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3363 0.2768 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3459 0.2764 sec/batch
# Nearest to between: prabang, gymnosperms, unfermented, half, ptb, cosmological, therapists, affected,
# Nearest to states: socialist, relations, manger, edelweiss, dail, interim, united, tamers,
# Nearest to five: zero, utc, unpaved, two, pankhurst, four, years, lakers,
# Nearest to zero: seven, two, migrant, five, ivoire, average, six, infant,
# Nearest to use: varying, parent, redshifted, watcher, testing, vodafone, davenport, nevers,
# Nearest to known: bessel, dismutase, bando, citizenry, janis, brushed, pouch, tibetan,
# Nearest to used: aford, flu, bundling, cervical, carelessness, format, sequencer, supports,
# Nearest to three: seven, six, eight, zero, unpaved, two, formerly, tz,
# Nearest to nobel: attar, composer, physicist, harriet, cameron, belmont, inaccessibility, interpretations,
# Nearest to paris: virgins, dembski, mae, hulme, berchtesgaden, tunku, vigo, great,
# Nearest to question: misinterpreted, clarified, teach, disapprove, neurophysiology, creation, egoism, ebu,
# Nearest to mean: dmt, originals, vestiges, ecclesia, sx, subtracted, madness, pronounced,
# Nearest to discovered: ambient, boggy, viol, reincarnations, noting, widespread, tempering, summaries,
# Nearest to know: polonaise, else, shakuhachi, hmong, alliteration, ish, abstractly, offence,
# Nearest to orthodox: oriental, sniffing, contemporaries, rancher, sacred, priests, terengganu, beliefs,
# Nearest to bible: tanakh, successively, old, distinguishing, sees, sneaking, textual, savate,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3400 0.2805 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2874 0.2820 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3625 0.2785 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3680 0.2793 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.4078 0.2806 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2958 0.2780 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.2802 0.2757 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3328 0.2760 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2169 0.2751 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.3174 0.2778 sec/batch
# Nearest to between: half, unfermented, prabang, gymnosperms, therapists, affected, ptb, cosmological,
# Nearest to states: socialist, dail, manger, edelweiss, united, congress, relations, tran,
# Nearest to five: zero, two, pankhurst, utc, unpaved, four, years, three,
# Nearest to zero: two, seven, migrant, five, ivoire, infant, six, three,
# Nearest to use: varying, redshifted, watcher, parent, vodafone, nevers, testing, davenport,
# Nearest to known: bessel, bando, dismutase, janis, citizenry, tibetan, repressor, septum,
# Nearest to used: bundling, flu, aford, cervical, supports, carelessness, propagation, format,
# Nearest to three: seven, six, eight, zero, two, five, unpaved, aristides,
# Nearest to nobel: attar, physicist, harriet, composer, cameron, belmont, inaccessibility, recipients,
# Nearest to paris: virgins, mae, dembski, berchtesgaden, hulme, kiel, vigo, tunku,
# Nearest to question: misinterpreted, clarified, disapprove, ebu, neurophysiology, teach, egoism, obeys,
# Nearest to mean: originals, dmt, sx, subtracted, vestiges, ecclesia, elliptic, postulates,
# Nearest to discovered: ambient, boggy, viol, reincarnations, noting, fights, summaries, tempering,
# Nearest to know: polonaise, else, alliteration, listen, offence, his, thinkers, abstractly,
# Nearest to orthodox: oriental, contemporaries, sniffing, rancher, sacred, terengganu, meticulously, priests,
# Nearest to bible: successively, distinguishing, textual, tanakh, old, sneaking, just, runestone,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.2906 0.2821 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.2555 0.2777 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3229 0.1223 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2391 0.2768 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2152 0.2791 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2048 0.2776 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2190 0.2774 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2214 0.2759 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2243 0.2800 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1846 0.2798 sec/batch
# Nearest to between: half, unfermented, prabang, moshoeshoe, therapists, gymnosperms, affected, invaders,
# Nearest to states: socialist, abolishing, dail, tran, united, manger, congress, relations,
# Nearest to five: zero, two, utc, unpaved, pankhurst, years, four, three,
# Nearest to zero: two, seven, five, migrant, three, six, ivoire, infant,
# Nearest to use: varying, watcher, nevers, redshifted, vodafone, parent, davenport, testing,
# Nearest to known: bessel, bando, dismutase, janis, repressor, spaceflights, tibetan, pouch,
# Nearest to used: bundling, flu, carelessness, aford, cervical, spears, sequencer, festive,
# Nearest to three: seven, six, zero, two, eight, five, unpaved, nader,
# Nearest to nobel: attar, physicist, cameron, inaccessibility, composer, shaman, harriet, recipients,
# Nearest to paris: virgins, berchtesgaden, dembski, bai, hulme, mae, mussorgsky, tunku,
# Nearest to question: misinterpreted, clarified, ebu, disapprove, neurophysiology, egoism, teach, obeys,
# Nearest to mean: originals, dmt, vestiges, sx, ethers, elliptic, subtracted, postulates,
# Nearest to discovered: ambient, boggy, viol, reincarnations, pliny, summaries, tempering, affordability,
# Nearest to know: polonaise, else, alliteration, thinkers, honest, falling, offence, abstractly,
# Nearest to orthodox: oriental, contemporaries, sacred, rancher, sniffing, priests, martyrs, terengganu,
# Nearest to bible: tanakh, old, textual, distinguishing, successively, chapters, targum, hebrew,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2566 0.2891 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2305 0.2845 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2206 0.3005 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1279 0.2897 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1747 0.2852 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1838 0.2786 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1583 0.2773 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1884 0.2787 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.1988 0.2777 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1890 0.2845 sec/batch
# Nearest to between: half, unfermented, prabang, therapists, affected, moshoeshoe, gymnosperms, coincides,
# Nearest to states: abolishing, dail, tran, manger, united, socialist, congress, relations,
# Nearest to five: zero, utc, two, pankhurst, three, four, years, unpaved,
# Nearest to zero: two, seven, five, migrant, three, average, six, infant,
# Nearest to use: varying, vodafone, watcher, nevers, parent, redshifted, testing, davenport,
# Nearest to known: bando, bessel, dismutase, spaceflights, pouch, repressor, janis, tibetan,
# Nearest to used: bundling, cervical, carelessness, aford, flu, propagation, tubes, festive,
# Nearest to three: seven, zero, two, six, five, eight, unpaved, nader,
# Nearest to nobel: attar, physicist, shaman, inaccessibility, cameron, belmont, harriet, ume,
# Nearest to paris: virgins, hulme, bai, berchtesgaden, mae, dembski, mussorgsky, portmanteau,
# Nearest to question: misinterpreted, ebu, disapprove, neurophysiology, abuser, teach, tunneling, egoism,
# Nearest to mean: originals, dmt, vestiges, subtracted, ethers, ecclesia, sx, varepsilon,
# Nearest to discovered: ambient, boggy, viol, reincarnations, oxycoccus, pliny, tempering, viaje,
# Nearest to know: polonaise, alliteration, else, listen, falling, halen, regarding, offence,
# Nearest to orthodox: oriental, contemporaries, sacred, sniffing, rancher, martyrs, conferring, matrimony,
# Nearest to bible: tanakh, old, distinguishing, targum, chapters, successively, textual, lds,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1447 0.2781 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2042 0.2787 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1821 0.2780 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1658 0.2782 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1834 0.2784 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1923 0.2764 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.2058 0.2768 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1559 0.2752 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1414 0.2813 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1816 0.2812 sec/batch
# Nearest to between: half, unfermented, prabang, moshoeshoe, formalism, therapists, supergravity, religio,
# Nearest to states: united, abolishing, dail, tran, congress, socialist, manger, relations,
# Nearest to five: zero, two, three, utc, four, years, pankhurst, seven,
# Nearest to zero: two, seven, five, migrant, three, six, one, infant,
# Nearest to use: watcher, vodafone, nevers, varying, redshifted, testing, davenport, bao,
# Nearest to known: bessel, dismutase, bando, repressor, spaceflights, pouch, jscript, sweeter,
# Nearest to used: bundling, cervical, carelessness, thecrimson, propagation, aford, flu, bassoons,
# Nearest to three: seven, two, zero, six, five, eight, est, nine,
# Nearest to nobel: attar, physicist, inaccessibility, shaman, placidia, cameron, belmont, prize,
# Nearest to paris: virgins, hulme, mae, berchtesgaden, bai, dembski, rotterdam, mussorgsky,
# Nearest to question: misinterpreted, ebu, disapprove, obeys, tunneling, egoism, clarified, abuser,
# Nearest to mean: dmt, originals, vestiges, sunday, subtracted, ethers, postulates, ecclesia,
# Nearest to discovered: boggy, ambient, viol, pliny, viaje, reincarnations, oxycoccus, tempering,
# Nearest to know: polonaise, falling, else, alliteration, halen, listen, regarding, offence,
# Nearest to orthodox: oriental, eastern, rancher, conferring, testifies, sniffing, matrimony, martyrs,
# Nearest to bible: tanakh, old, textual, targum, distinguishing, successively, runestone, chapters,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.1881 0.2855 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1494 0.2825 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1637 0.2816 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1925 0.2770 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1474 0.2795 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1291 0.2793 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1723 0.2769 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1409 0.2814 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1843 0.2811 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2019 0.2828 sec/batch
# Nearest to between: half, unfermented, prabang, formalism, moshoeshoe, invaders, ler, deluge,
# Nearest to states: congress, dail, united, manger, norouz, tran, abolishing, socialist,
# Nearest to five: zero, two, three, four, pankhurst, years, seven, utc,
# Nearest to zero: two, seven, five, three, one, six, migrant, nine,
# Nearest to use: vodafone, varying, watcher, redshifted, nevers, testing, pressed, bao,
# Nearest to known: bessel, bando, singhasari, repressor, chalukyas, dismutase, late, citizenry,
# Nearest to used: bundling, thecrimson, carelessness, cervical, supports, stonemasons, omit, flu,
# Nearest to three: seven, two, zero, six, five, eight, one, four,
# Nearest to nobel: attar, physicist, prize, medicine, inaccessibility, belmont, harriet, shaman,
# Nearest to paris: virgins, hulme, berchtesgaden, mae, bai, kiel, rotterdam, crowning,
# Nearest to question: misinterpreted, ebu, disapprove, abuser, kazimierz, obeys, wiles, syllogisms,
# Nearest to mean: originals, dmt, sunday, subtracted, vestiges, ethers, ecclesia, sx,
# Nearest to discovered: boggy, viol, ambient, pliny, viaje, oxycoccus, reincarnations, pangaea,
# Nearest to know: polonaise, else, halen, falling, alliteration, listen, regarding, ish,
# Nearest to orthodox: oriental, conferring, martyrs, rancher, eastern, adventist, icon, contemporaries,
# Nearest to bible: targum, old, tanakh, runestone, successively, distinguishing, lds, textual,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.1991 0.2859 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1651 0.2789 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1494 0.2746 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1750 0.2776 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0261 0.2798 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1292 0.2760 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1523 0.2763 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1051 0.2767 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1614 0.0460 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1277 0.2772 sec/batch
# Nearest to between: half, unfermented, formalism, moshoeshoe, type, affected, ler, prabang,
# Nearest to states: united, dail, congress, abolishing, norouz, manger, tran, edelweiss,
# Nearest to five: zero, two, three, four, utc, seven, six, pankhurst,
# Nearest to zero: two, five, seven, three, six, migrant, one, four,
# Nearest to use: watcher, vodafone, varying, redshifted, nevers, bao, testing, beginners,
# Nearest to known: bessel, bando, repressor, dismutase, spaceflights, aquarii, moraines, chalukyas,
# Nearest to used: bundling, flu, cervical, stonemasons, omit, thecrimson, spears, reconnaissance,
# Nearest to three: two, zero, seven, six, five, eight, four, one,
# Nearest to nobel: attar, physicist, prize, shaman, inaccessibility, medicine, placidia, electrodynamics,
# Nearest to paris: virgins, berchtesgaden, bai, mae, hulme, kiel, rotterdam, fashionable,
# Nearest to question: misinterpreted, ebu, abuser, disapprove, obeys, syllogisms, deranged, clarified,
# Nearest to mean: originals, elliptic, postulates, subtracted, sx, sunday, ecclesia, dmt,
# Nearest to discovered: boggy, ambient, viol, viaje, oxycoccus, pliny, pangaea, reincarnations,
# Nearest to know: polonaise, else, halen, alliteration, falling, frightened, regarding, listen,
# Nearest to orthodox: oriental, rancher, adventist, conferring, seminars, sniffing, faunal, icon,
# Nearest to bible: tanakh, targum, lds, runestone, old, successively, textual, lycaon,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0940 0.2784 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0621 0.2815 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0935 0.2817 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0491 0.2809 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0584 0.2788 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0136 0.2770 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0979 0.2797 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.1092 0.2797 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1194 0.2784 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0664 0.2791 sec/batch
# Nearest to between: half, moshoeshoe, prabang, unfermented, affected, formalism, supergravity, anaphylaxis,
# Nearest to states: abolishing, united, dail, norouz, congress, tran, manger, relations,
# Nearest to five: zero, two, three, four, utc, years, pankhurst, seven,
# Nearest to zero: two, seven, five, three, migrant, six, one, four,
# Nearest to use: vodafone, nevers, watcher, pressed, redshifted, bao, varying, testing,
# Nearest to known: bessel, bando, repressor, spaceflights, dismutase, tibetan, sweeter, moraines,
# Nearest to used: bundling, reconnaissance, flu, sometimes, stonemasons, spears, custom, omit,
# Nearest to three: two, zero, seven, six, five, eight, four, one,
# Nearest to nobel: attar, physicist, prize, inaccessibility, medicine, placidia, electrodynamics, shaman,
# Nearest to paris: berchtesgaden, virgins, hulme, mae, bai, stuttgart, fashionable, kiel,
# Nearest to question: misinterpreted, ebu, abuser, syllogisms, disapprove, wiles, liability, obeys,
# Nearest to mean: originals, subtracted, sunday, postulates, vestiges, dmt, sx, elliptic,
# Nearest to discovered: boggy, ambient, pangaea, pliny, oxycoccus, viol, viaje, explored,
# Nearest to know: polonaise, halen, else, falling, chile, alliteration, frightened, regarding,
# Nearest to orthodox: oriental, rancher, prologue, conferring, matrimony, adventist, icon, sniffing,
# Nearest to bible: old, targum, tanakh, lds, chapters, textual, judaica, runestone,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0208 0.2820 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0122 0.2772 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0047 0.2775 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0738 0.2765 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0727 0.2818 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0656 0.2766 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0727 0.2757 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.0876 0.2784 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0813 0.2755 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0240 0.2781 sec/batch
# Nearest to between: half, formalism, moshoeshoe, division, affected, supergravity, silvery, type,
# Nearest to states: united, abolishing, congress, dail, tran, norouz, manger, relations,
# Nearest to five: zero, three, two, four, utc, pankhurst, years, six,
# Nearest to zero: two, five, seven, three, six, one, migrant, infant,
# Nearest to use: vodafone, nevers, watcher, pressed, redshifted, bao, testing, velarized,
# Nearest to known: bando, bessel, spaceflights, repressor, dismutase, ornella, tibetan, moraines,
# Nearest to used: bundling, sometimes, omit, bassoons, stonemasons, cervical, thecrimson, reconnaissance,
# Nearest to three: two, zero, six, seven, five, eight, four, one,
# Nearest to nobel: attar, inaccessibility, prize, placidia, physicist, medicine, shaman, electrodynamics,
# Nearest to paris: hulme, bai, berchtesgaden, virgins, mae, stuttgart, fashionable, westerner,
# Nearest to question: misinterpreted, ebu, syllogisms, disapprove, abuser, teleological, obeys, wiles,
# Nearest to mean: subtracted, vestiges, postulates, sunday, originals, dmt, cmmi, quadrupole,
# Nearest to discovered: boggy, ambient, viaje, pliny, pangaea, oxycoccus, planets, explored,
# Nearest to know: polonaise, halen, falling, chile, else, sequence, frightened, alliteration,
# Nearest to orthodox: oriental, rancher, eastern, matrimony, conferring, adventist, iff, scythians,
# Nearest to bible: targum, old, tanakh, judaica, runestone, chapters, lds, textual,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0634 0.2815 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0839 0.2783 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0777 0.2791 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0551 0.2766 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0715 0.2786 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0440 0.2796 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0633 0.2789 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0594 0.2826 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.1052 0.2817 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0623 0.2754 sec/batch
# Nearest to between: moshoeshoe, half, formalism, deluge, division, invaders, prabang, singleton,
# Nearest to states: united, congress, abolishing, norouz, dail, tran, seaport, manger,
# Nearest to five: zero, two, three, four, utc, years, six, seven,
# Nearest to zero: two, five, seven, three, six, one, migrant, four,
# Nearest to use: vodafone, nevers, pressed, velarized, watcher, bao, redshifted, varying,
# Nearest to known: bando, bessel, spaceflights, repressor, chalukyas, singhasari, studying, dismutase,
# Nearest to used: omit, sometimes, reconnaissance, bundling, bassoons, beheaded, welded, cervical,
# Nearest to three: zero, two, six, seven, five, eight, four, one,
# Nearest to nobel: prize, physicist, attar, inaccessibility, placidia, electrodynamics, medicine, shaman,
# Nearest to paris: hulme, mae, berchtesgaden, bai, stuttgart, virgins, mer, architectural,
# Nearest to question: misinterpreted, ebu, disapprove, abuser, blasts, syllogisms, wiles, publications,
# Nearest to mean: sunday, subtracted, originals, postulates, climatic, vestiges, dmt, risch,
# Nearest to discovered: boggy, pliny, viaje, planets, ambient, oxycoccus, pangaea, explored,
# Nearest to know: polonaise, halen, else, chile, falling, frightened, sequence, alliteration,
# Nearest to orthodox: oriental, rancher, conferring, westminsters, scythians, eastern, icon, akihabara,
# Nearest to bible: targum, old, runestone, tanakh, successively, lds, judaica, textual,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0759 0.2807 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0085 0.2751 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0657 0.2768 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0726 0.2771 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0816 0.2772 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1225 0.2763 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1310 0.2772 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0570 0.2775 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0373 0.2776 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0661 0.2730 sec/batch
# Nearest to between: half, moshoeshoe, formalism, deluge, supergravity, division, silvery, affected,
# Nearest to states: united, congress, abolishing, norouz, dail, tran, unconstitutional, seaport,
# Nearest to five: zero, two, three, four, utc, six, seven, years,
# Nearest to zero: five, two, seven, three, one, six, migrant, four,
# Nearest to use: velarized, vodafone, pressed, watcher, nevers, bao, testing, varying,
# Nearest to known: bando, bessel, tibetan, linz, chalukyas, spaceflights, ornella, repressor,
# Nearest to used: reconnaissance, omit, bundling, thecrimson, custom, sometimes, bassoons, welded,
# Nearest to three: two, zero, six, seven, five, eight, four, nine,
# Nearest to nobel: prize, inaccessibility, electrodynamics, physicist, attar, medicine, placidia, shaman,
# Nearest to paris: berchtesgaden, fashionable, mae, bai, stuttgart, virgins, hulme, westerner,
# Nearest to question: misinterpreted, ebu, disapprove, abuser, syllogisms, blasts, wiles, ccitt,
# Nearest to mean: sunday, originals, risch, climatic, dmt, subtracted, vestiges, cmmi,
# Nearest to discovered: viaje, boggy, pliny, oxycoccus, explored, planets, nerva, ambient,
# Nearest to know: halen, polonaise, chile, else, frightened, sequence, falling, regarding,
# Nearest to orthodox: oriental, icon, conferring, rancher, iff, adventist, prologue, wight,
# Nearest to bible: targum, old, runestone, tanakh, successively, lycaon, lds, judaica,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 4.0133 0.2806 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0341 0.2766 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0326 0.2788 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0349 0.2815 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0905 0.2799 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0550 0.2505 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0236 0.2797 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9902 0.2804 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0182 0.2762 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9911 0.2759 sec/batch
# Nearest to between: half, moshoeshoe, singleton, type, division, formalism, deluge, affected,
# Nearest to states: united, norouz, abolishing, congress, tran, unconstitutional, seaport, dail,
# Nearest to five: zero, two, three, four, six, seven, utc, eight,
# Nearest to zero: two, five, seven, three, six, one, four, nine,
# Nearest to use: velarized, vodafone, nevers, watcher, pressed, testing, bao, beginners,
# Nearest to known: bando, bessel, spaceflights, dismutase, ornella, chalukyas, tibetan, late,
# Nearest to used: reconnaissance, bundling, omit, custom, welded, sometimes, acronym, stonemasons,
# Nearest to three: two, zero, six, seven, five, eight, four, one,
# Nearest to nobel: prize, physicist, attar, inaccessibility, electrodynamics, medicine, placidia, xaver,
# Nearest to paris: virgins, berchtesgaden, fashionable, bai, hulme, mae, stuttgart, progressing,
# Nearest to question: misinterpreted, ebu, disapprove, abuser, ostrogoth, wiles, teleological, syllogisms,
# Nearest to mean: sunday, risch, originals, cmmi, postulates, vestiges, sx, subtracted,
# Nearest to discovered: viaje, boggy, explored, pliny, oxycoccus, nerva, conceived, ambient,
# Nearest to know: halen, polonaise, else, chile, regarding, frightened, falling, sequence,
# Nearest to orthodox: oriental, rancher, icon, prologue, adventist, wight, scythians, westminsters,
# Nearest to bible: targum, old, runestone, tanakh, chapters, chronicles, lds, successively,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 4.0061 0.2842 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9355 0.2770 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 3.9862 0.2774 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0190 0.2763 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0175 0.2765 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 4.0251 0.2789 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9316 0.2764 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9640 0.2769 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9578 0.2759 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9574 0.2761 sec/batch
# Nearest to between: moshoeshoe, singleton, half, type, division, silvery, supergravity, moheli,
# Nearest to states: united, abolishing, norouz, congress, communal, tran, unconstitutional, seaport,
# Nearest to five: zero, two, three, four, seven, six, eight, years,
# Nearest to zero: five, two, seven, three, one, six, four, migrant,
# Nearest to use: vodafone, nevers, pressed, velarized, watcher, testing, bao, beginners,
# Nearest to known: bando, bessel, spaceflights, sweeter, dismutase, moraines, studying, chalukyas,
# Nearest to used: reconnaissance, custom, acronym, welded, stonemasons, bassoons, bundling, sometimes,
# Nearest to three: two, zero, six, seven, five, four, eight, one,
# Nearest to nobel: prize, physicist, electrodynamics, attar, inaccessibility, placidia, medicine, shaman,
# Nearest to paris: hulme, fashionable, berchtesgaden, bai, pour, la, virgins, mae,
# Nearest to question: misinterpreted, ebu, disapprove, wiles, abuser, ostrogoth, purport, syllogisms,
# Nearest to mean: vestiges, risch, sunday, climatic, cmmi, dmt, recurs, postulates,
# Nearest to discovered: viaje, boggy, explored, oxycoccus, pliny, conceived, duopoly, ambient,
# Nearest to know: halen, chile, polonaise, else, falling, frightened, regarding, sequence,
# Nearest to orthodox: oriental, adventist, ladino, prologue, rancher, calendrical, icon, eastern,
# Nearest to bible: targum, old, chapters, lds, tanakh, runestone, rashi, judaica,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.9943 0.2806 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 4.0285 0.2754 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9527 0.2776 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.0261 0.2767 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0153 0.2771 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9578 0.2769 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 4.0008 0.2763 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 4.0268 0.2780 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 4.0004 0.2763 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 3.9975 0.2737 sec/batch
# Nearest to between: moshoeshoe, singleton, half, formalism, handedness, deluge, division, silvery,
# Nearest to states: united, abolishing, congress, norouz, unconstitutional, tran, communal, socialist,
# Nearest to five: zero, three, two, four, seven, six, eight, one,
# Nearest to zero: five, two, seven, three, one, six, four, nine,
# Nearest to use: vodafone, nevers, overturn, velarized, bao, pressed, watcher, fairchild,
# Nearest to known: bando, bessel, spaceflights, dismutase, as, ornella, repressor, chalukyas,
# Nearest to used: reconnaissance, acronym, omit, sometimes, bassoons, custom, stonemasons, welded,
# Nearest to three: two, zero, seven, six, five, eight, one, four,
# Nearest to nobel: prize, physicist, electrodynamics, inaccessibility, attar, placidia, amyloid, medicine,
# Nearest to paris: hulme, pour, berchtesgaden, fashionable, mae, virgins, de, la,
# Nearest to question: misinterpreted, ebu, disapprove, wiles, ostrogoth, publications, abuser, teleological,
# Nearest to mean: risch, vestiges, dmt, sunday, quadrupole, postulates, climatic, cmmi,
# Nearest to discovered: viaje, boggy, pliny, explored, oxycoccus, ellipses, duopoly, ambient,
# Nearest to know: halen, else, polonaise, chile, falling, regarding, ish, say,
# Nearest to orthodox: oriental, eastern, adventist, matrimony, autocephalous, icon, chrismation, calendrical,
# Nearest to bible: targum, old, lds, tanakh, chapters, rashi, runestone, judaica,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 4.0243 0.2803 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9763 0.2773 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9583 0.2789 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 4.0056 0.2748 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0101 0.2751 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 3.9687 0.2786 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9947 0.2768 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9953 0.2759 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9548 0.2759 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0272 0.2786 sec/batch
# Nearest to between: singleton, moshoeshoe, deluge, half, formalism, broadly, division, affected,
# Nearest to states: united, congress, abolishing, norouz, unconstitutional, communal, prohibits, relations,
# Nearest to five: zero, three, two, four, seven, six, eight, one,
# Nearest to zero: five, two, seven, three, one, six, four, eight,
# Nearest to use: vodafone, velarized, nevers, pressed, bao, fairchild, overturn, testing,
# Nearest to known: bando, bessel, as, studying, dismutase, spaceflights, chalukyas, repressor,
# Nearest to used: reconnaissance, omit, acronym, sometimes, welded, bundling, bassoons, custom,
# Nearest to three: two, zero, six, seven, five, four, eight, one,
# Nearest to nobel: prize, physicist, electrodynamics, inaccessibility, attar, placidia, amyloid, medicine,
# Nearest to paris: fashionable, pour, hulme, berchtesgaden, architectural, virgins, la, de,
# Nearest to question: misinterpreted, ebu, disapprove, wiles, ccitt, blasts, banishment, syllogisms,
# Nearest to mean: risch, sunday, climatic, dmt, vestiges, cmmi, daylight, recurs,
# Nearest to discovered: viaje, boggy, oxycoccus, pliny, explored, nerva, ellipses, conceived,
# Nearest to know: halen, chile, else, polonaise, say, regarding, frightened, falling,
# Nearest to orthodox: oriental, adventist, icon, chrismation, matrimony, catechism, prologue, calendrical,
# Nearest to bible: targum, old, lds, tanakh, runestone, judaica, silica, chapters,
# Epoch 5/10 Iteration: 22100 Avg. Training loss: 3.9910 0.2819 sec/batch
# Epoch 5/10 Iteration: 22200 Avg. Training loss: 4.0958 0.2761 sec/batch
# Epoch 5/10 Iteration: 22300 Avg. Training loss: 4.0251 0.2779 sec/batch
# ...
# Nearest to between: relationship, dichotomy, bonds, type, singleton, sex, ionization, affected,
# Nearest to states: united, congress, missouri, unconstitutional, abolishing, prohibits, familycolor, ams,
# Nearest to five: zero, three, two, seven, four, six, eight, one,
# Nearest to zero: five, two, three, one, seven, four, six, eight,
# Nearest to use: vodafone, carbamazepine, or, used, fairchild, nevers, nni, bao,
# Nearest to known: as, the, bando, for, is, since, various, mandaeanism,
# Nearest to used: reconnaissance, sometimes, acronym, to, some, was, gaits, use,
# Nearest to three: two, five, six, zero, four, one, seven, eight,
# Nearest to nobel: prize, physicist, laureate, amyloid, electrodynamics, ionizing, chemist, milosevic,
# Nearest to paris: pour, soir, monsieur, marseille, virgins, progressing, ferrol, idealised,
# Nearest to question: search, ebu, purport, teleological, blasts, considering, tunneling, treading,
# Nearest to mean: risch, postulates, weighting, pasts, monophosphate, yah, hottest, recurs,
# Nearest to discovered: oxycoccus, ellipses, radium, viaje, mathematician, found, cebit, duopoly,
# Nearest to know: halen, say, https, dummies, want, you, chile, ish,
# Nearest to orthodox: feste, oriental, zagreb, chrismation, autocephalous, rancher, rite, prologue,
# Nearest to bible: targum, old, farmer, criticise, lds, successively, rashi, books,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8239 0.2808 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8431 0.2775 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8640 0.2796 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8400 0.2754 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8750 0.2824 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8767 0.2795 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8231 0.2755 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8526 0.2774 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8594 0.2786 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8893 0.2773 sec/batch
# Nearest to between: relationship, and, dichotomy, bonds, singleton, at, ruthenians, ionization,
# Nearest to states: united, congress, familycolor, missouri, ams, prohibits, lattimore, unconstitutional,
# Nearest to five: zero, three, two, seven, six, four, eight, one,
# Nearest to zero: five, two, three, one, seven, four, six, eight,
# Nearest to use: vodafone, used, carbamazepine, using, or, fairchild, nni, velarized,
# Nearest to known: as, the, for, of, bando, since, and, mandaeanism,
# Nearest to used: sometimes, to, reconnaissance, was, acronym, or, as, some,
# Nearest to three: two, six, five, four, zero, seven, one, eight,
# Nearest to nobel: prize, physicist, amyloid, electrodynamics, ionizing, laureate, milosevic, convertibility,
# Nearest to paris: pour, soir, marseille, monsieur, ferrol, fashionable, virgins, berchtesgaden,
# Nearest to question: search, ebu, purport, teleological, considering, treading, whether, blasts,
# Nearest to mean: risch, postulates, weighting, quadrupole, monophosphate, hottest, yah, recurs,
# Nearest to discovered: ellipses, oxycoccus, found, viaje, radium, planets, extrasolar, mathematician,
# Nearest to know: halen, https, say, want, you, chile, dummies, man,
# Nearest to orthodox: oriental, autocephalous, chrismation, feste, zagreb, patriarchate, rite, rancher,
# Nearest to bible: targum, old, lds, criticise, farmer, successively, rashi, nrsv,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8621 0.2811 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8746 0.2761 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8109 0.2770 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8373 0.2762 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.8964 0.2768 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8287 0.2808 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9617 0.2753 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.8890 0.2762 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.8983 0.2762 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8278 0.2810 sec/batch
# Nearest to between: relationship, and, singleton, dichotomy, ruthenians, ionization, marija, sex,
# Nearest to states: united, congress, familycolor, missouri, unconstitutional, texas, prohibits, war,
# Nearest to five: zero, three, two, four, six, seven, eight, one,
# Nearest to zero: two, five, one, three, four, seven, six, eight,
# Nearest to use: used, vodafone, using, or, carbamazepine, for, velarized, nni,
# Nearest to known: as, the, for, bando, since, of, is, on,
# Nearest to used: reconnaissance, sometimes, to, acronym, was, use, as, refer,
# Nearest to three: two, six, five, four, zero, seven, one, eight,
# Nearest to nobel: prize, physicist, laureate, amyloid, electrodynamics, milosevic, chemist, buchenwald,
# Nearest to paris: pour, soir, marseille, monsieur, ferrol, georges, fashionable, du,
# Nearest to question: ebu, search, purport, ccitt, teleological, kamchatsky, asked, considering,
# Nearest to mean: risch, weighting, postulates, quadrupole, monophosphate, yah, recurs, pasts,
# Nearest to discovered: oxycoccus, ellipses, viaje, radium, found, mathematician, planets, duopoly,
# Nearest to know: halen, say, want, https, you, how, chile, dummies,
# Nearest to orthodox: feste, zagreb, oriental, chrismation, autocephalous, prologue, rancher, patriarchate,
# Nearest to bible: targum, old, farmer, lds, successively, criticise, rashi, junction,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.7939 0.2790 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8792 0.2752 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.7679 0.2771 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8689 0.2758 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8813 0.2755 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8597 0.2775 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.8988 0.1324 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.7922 0.2757 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8567 0.2782 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8583 0.2757 sec/batch
# Nearest to between: relationship, singleton, dichotomy, marija, ruthenians, sex, and, differences,
# Nearest to states: united, congress, missouri, unconstitutional, familycolor, texas, hawaii, ams,
# Nearest to five: zero, three, two, four, seven, six, eight, one,
# Nearest to zero: two, five, three, four, seven, one, six, eight,
# Nearest to use: carbamazepine, using, used, vodafone, giantesses, or, nni, iconoclastic,
# Nearest to known: as, the, for, is, bando, on, in, since,
# Nearest to used: sometimes, reconnaissance, to, refer, was, acronym, as, some,
# Nearest to three: two, six, five, four, seven, zero, one, eight,
# Nearest to nobel: prize, physicist, laureate, amyloid, electrodynamics, milosevic, buchenwald, placate,
# Nearest to paris: pour, soir, marseille, ferrol, monsieur, virgins, georges, progressing,
# Nearest to question: search, ebu, purport, ccitt, kamchatsky, teleological, asked, whether,
# Nearest to mean: risch, weighting, monophosphate, pasts, postulates, yah, hottest, apr,
# Nearest to discovered: oxycoccus, ellipses, found, viaje, radium, cebit, named, duopoly,
# Nearest to know: halen, say, how, want, https, you, man, dummies,
# Nearest to orthodox: feste, zagreb, oriental, autocephalous, chrismation, prologue, rancher, serbo,
# Nearest to bible: targum, old, farmer, lds, criticise, successively, junction, nrsv,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8081 0.2812 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8269 0.2758 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.8199 0.2763 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.7862 0.2758 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8880 0.2766 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8728 0.2763 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8743 0.2760 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7535 0.2778 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.8124 0.2769 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.7964 0.2751 sec/batch
# Nearest to between: relationship, and, singleton, dichotomy, the, type, moheli, marija,
# Nearest to states: united, congress, familycolor, missouri, fifth, dozen, unconstitutional, proteobacteria,
# Nearest to five: zero, three, two, four, seven, six, eight, one,
# Nearest to zero: five, two, three, four, seven, one, six, eight,
# Nearest to use: carbamazepine, or, used, vodafone, for, from, using, giantesses,
# Nearest to known: as, the, is, for, on, in, of, bando,
# Nearest to used: sometimes, to, reconnaissance, some, as, acronym, also, was,
# Nearest to three: two, five, four, six, zero, seven, one, eight,
# Nearest to nobel: prize, physicist, amyloid, laureate, electrodynamics, milosevic, buchenwald, avtovaz,
# Nearest to paris: pour, monsieur, soir, marseille, georges, ferrol, progressing, idealised,
# Nearest to question: search, purport, ebu, teleological, ccitt, questions, judgements, kamchatsky,
# Nearest to mean: risch, weighting, quadrupole, hottest, average, pasts, yah, monophosphate,
# Nearest to discovered: oxycoccus, found, ellipses, radium, cebit, viaje, duopoly, extrasolar,
# Nearest to know: halen, say, want, how, you, https, dummies, man,
# Nearest to orthodox: feste, zagreb, autocephalous, chrismation, oriental, serbo, rancher, prologue,
# Nearest to bible: targum, old, lds, criticise, books, farmer, nrsv, rashi,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7516 0.2808 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8046 0.2759 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8558 0.2751 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8559 0.2765 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8257 0.2740 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.8751 0.2768 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8488 0.2767 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8229 0.2759 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8224 0.2758 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8312 0.2746 sec/batch
# Nearest to between: relationship, and, dichotomy, type, ionization, singleton, sex, moheli,
# Nearest to states: united, congress, familycolor, missouri, ams, fifth, prohibits, texas,
# Nearest to five: zero, three, two, four, seven, six, eight, one,
# Nearest to zero: five, two, three, one, seven, four, six, eight,
# Nearest to use: carbamazepine, vodafone, or, using, nni, used, hydroponics, fairchild,
# Nearest to known: as, the, for, is, by, bando, since, of,
# Nearest to used: sometimes, to, was, as, reconnaissance, some, acronym, refer,
# Nearest to three: two, five, six, four, one, seven, zero, eight,
# Nearest to nobel: prize, amyloid, electrodynamics, physicist, laureate, milosevic, buna, convertibility,
# Nearest to paris: pour, monsieur, soir, marseille, georges, idealised, du, hautes,
# Nearest to question: search, purport, ebu, questions, ccitt, teleological, whether, judgements,
# Nearest to mean: risch, weighting, pasts, quadrupole, postulates, hottest, monophosphate, dmt,
# Nearest to discovered: oxycoccus, ellipses, found, viaje, radium, planets, discoveries, cebit,
# Nearest to know: halen, say, how, want, https, you, man, dummies,
# Nearest to orthodox: feste, oriental, chrismation, autocephalous, zagreb, patriarchate, rite, prologue,
# Nearest to bible: targum, old, criticise, lds, farmer, books, rashi, nrsv,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8818 0.2790 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8176 0.2751 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8345 0.2796 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8429 0.2801 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8642 0.2805 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8577 0.2811 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8359 0.2793 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8306 0.2762 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.8254 0.2780 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8068 0.2748 sec/batch
# Nearest to between: relationship, and, dichotomy, the, differences, ionization, moheli, marija,
# Nearest to states: united, congress, unconstitutional, familycolor, fifth, missouri, texas, any,
# Nearest to five: zero, three, two, four, six, seven, eight, one,
# Nearest to zero: five, two, one, three, four, seven, six, eight,
# Nearest to use: for, or, using, used, vodafone, carbamazepine, from, there,
# Nearest to known: as, the, for, is, of, in, by, since,
# Nearest to used: sometimes, to, as, was, for, or, refer, use,
# Nearest to three: two, five, six, four, one, seven, eight, zero,
# Nearest to nobel: prize, amyloid, physicist, laureate, electrodynamics, milosevic, ionizing, convertibility,
# Nearest to paris: pour, monsieur, soir, marseille, georges, hautes, idealised, ferrol,
# Nearest to question: purport, search, ebu, questions, whether, asked, kamchatsky, considering,
# Nearest to mean: weighting, risch, quadrupole, pasts, hottest, yah, char, might,
# Nearest to discovered: found, oxycoccus, ellipses, radium, viaje, discoveries, brattain, compressor,
# Nearest to know: say, halen, how, want, you, https, dummies, what,
# Nearest to orthodox: feste, zagreb, oriental, chrismation, autocephalous, patriarchate, prologue, icon,
# Nearest to bible: targum, old, criticise, lds, farmer, nrsv, rashi, translation,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8457 0.2808 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8245 0.2786 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.8975 0.2772 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.9173 0.2773 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8894 0.2772 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8590 0.2763 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7933 0.2751 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8283 0.2752 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7117 0.2766 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8692 0.2772 sec/batch
# Nearest to between: relationship, and, dichotomy, marija, ionization, moheli, singleton, ruthenians,
# Nearest to states: united, congress, missouri, familycolor, texas, unconstitutional, sheet, ams,
# Nearest to five: zero, three, two, four, six, seven, eight, one,
# Nearest to zero: five, two, three, one, four, six, seven, nine,
# Nearest to use: used, using, carbamazepine, for, or, vodafone, arma, nni,
# Nearest to known: as, the, for, is, of, by, bando, and,
# Nearest to used: sometimes, to, was, reconnaissance, use, as, acronym, combination,
# Nearest to three: two, six, five, four, one, zero, seven, eight,
# Nearest to nobel: prize, physicist, laureate, electrodynamics, amyloid, chemist, milosevic, inaccessibility,
# Nearest to paris: pour, monsieur, soir, marseille, hautes, georges, idealised, ferrol,
# Nearest to question: search, purport, ebu, questions, asked, kamchatsky, whether, ccitt,
# Nearest to mean: weighting, quadrupole, makes, risch, pasts, postulates, calculating, hottest,
# Nearest to discovered: oxycoccus, found, ellipses, cebit, radium, brattain, named, duopoly,
# Nearest to know: halen, say, want, how, you, https, dummies, man,
# Nearest to orthodox: zagreb, feste, oriental, autocephalous, patriarchate, chrismation, prologue, serbo,
# Nearest to bible: targum, old, farmer, criticise, rashi, lds, bolstered, nrsv,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8236 0.2789 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8399 0.2791 sec/batch

# %%
#github error:
#remote: error: File checkpoints/text8.ckpt.data-00000-of-00001 is 292.05 MB; this exceeds GitHub's file size limit of 100.00 MB

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints\text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
